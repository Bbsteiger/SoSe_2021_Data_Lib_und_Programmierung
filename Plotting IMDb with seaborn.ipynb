# %% [markdown]
# Wir wollen mittels Python und dem Package seaborn einen Datenset der IMDb

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url =  "https://datasets.imdbws.com/title.ratings.tsv.gz"
imdb = pd.read_csv(url)

# %%
imdb
# Out:
#         tconst\taverageRating\tnumVotes
# 0                  tt0000001\t5.7\t1702
# 1                   tt0000002\t6.1\t210
# 2                  tt0000003\t6.5\t1462
# 3                   tt0000004\t6.2\t123
# 4                  tt0000005\t6.2\t2261
# ...                                 ...
# 1154741               tt9916682\t5.6\t5
# 1154742               tt9916690\t6.6\t5
# 1154743              tt9916720\t6.5\t82
# 1154744              tt9916766\t6.9\t17
# 1154745              tt9916778\t7.5\t27
#
# [1154746 rows x 1 columns]

# %%
# Um die Spalten durch Tabulatoren auftrennen zu lassen, müssen wir
# den Parameter sep setzen
imdb = pd.read_csv(url, sep="\t")

# %%
imdb.shape
# Out:
# (1154746, 3)

# %%
imdb["averageRating"]
# Out:
# 0          5.7
# 1          6.1
# 2          6.5
# 3          6.2
# 4          6.2
#           ...
# 1154741    5.6
# 1154742    6.6
# 1154743    6.5
# 1154744    6.9
# 1154745    7.5
# Name: averageRating, Length: 1154746, dtype: float64

# %%
imdb.averageRating
# Out:
# 0          5.7
# 1          6.1
# 2          6.5
# 3          6.2
# 4          6.2
#           ...
# 1154741    5.6
# 1154742    6.6
# 1154743    6.5
# 1154744    6.9
# 1154745    7.5
# Name: averageRating, Length: 1154746, dtype: float64

# %%
type(imdb.averageRating)
# Out:
# pandas.core.series.Series

# %%
imdb.averageRating.describe()
# Out:
# count    1.154746e+06
# mean     6.902455e+00
# std      1.399694e+00
# min      1.000000e+00
# 25%      6.100000e+00
# 50%      7.100000e+00
# 75%      7.900000e+00
# max      1.000000e+01
# Name: averageRating, dtype: float64

# %%
# Durchschnitt
imdb.averageRating.mean()
# Out:
# 6.902454652364725

# %%
# Median (= 50 Percentile)
imdb.averageRating
# Out:
# 0          5.7
# 1          6.1
# 2          6.5
# 3          6.2
# 4          6.2
#           ...
# 1154741    5.6
# 1154742    6.6
# 1154743    6.5
# 1154744    6.9
# 1154745    7.5
# Name: averageRating, Length: 1154746, dtype: float64

# %%
imdb.describe()
# Out:
#        averageRating      numVotes
# count   1.154746e+06  1.154746e+06
# mean    6.902455e+00  9.537327e+02
# std     1.399694e+00  1.611512e+04
# min     1.000000e+00  5.000000e+00
# 25%     6.100000e+00  9.000000e+00
# 50%     7.100000e+00  2.000000e+01
# 75%     7.900000e+00  7.900000e+01
# max     1.000000e+01  2.393961e+06

# %%
imdb.averageRating.hist()
# Out:
# <AxesSubplot:>

# %%
imdb.averageRating.hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
# %who
# Out:
# imdb	 imdb_subsample	 pd	 plt	 sns	 this	 url	 violin_plot

# %%
sns.boxplot(x=imdb.averageRating)
# Out:
# <AxesSubplot:xlabel='averageRating'>

# %%
sns.__version__
# Out:
# '0.11.0'

# %%
import this

# %%
sns.boxplot(y=imdb.averageRating)
# Out:
# <AxesSubplot:ylabel='averageRating'>

# %%
violin_plot = sns.violinplot(y=imdb.averageRating, color="green")

# %%
plt.savefig("Violin_plot_average_rating.pdf")

# %%
violin_plot.figure.savefig("Violin_plot_average_rating.pdf")

# %%
plt.close()

# %%
violin_plot.figure.savefig("Violin_plot_average_rating.jpg")

# %%
violin_plot.figure.savefig("Violin_plot_average_rating.png")

# %%
# Ein zufälliges Subset aus der Gesamtmenge extrahieren
# random_state ist ein beliebig gewählter Startwert
imdb_subsample = imdb.sample(10000, random_state=42)

# %%
imdb_subsample.shape
# Out:
# (10000, 3)

# %%
sns.stripplot(x=imdb_subsample.averageRating)
# Out:
# <AxesSubplot:xlabel='averageRating'>

# %%
sns.stripplot(x=imdb_subsample.averageRating, alpha=0.1)
# Out:
# <AxesSubplot:xlabel='averageRating'>

# %%
sns.stripplot(y=imdb_subsample.averageRating, alpha=0.05)
# Out:
# <AxesSubplot:ylabel='averageRating'>

# %%
sns.boxplot(x=imdb.averageRating)
sns.stripplot(x=imdb_subsample.averageRating, alpha=0.05)
# Out:
# <AxesSubplot:xlabel='averageRating'>

# %%
sns.swarmplot(y=imdb_subsample.averageRating)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-b91f4f771ca3> in <module>
# ----> 1 sns.swarmplot(y=imdb_subsample.averageRating)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    3004                        linewidth=linewidth))
#    3005
# -> 3006     plotter.plot(ax, kwargs)
#    3007     return ax
#    3008
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, kws)
#    1418     def plot(self, ax, kws):
#    1419         """Make the full plot."""
# -> 1420         self.draw_swarmplot(ax, kws)
#    1421         self.add_legend_data(ax)
#    1422         self.annotate_axes(ax)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in draw_swarmplot(self, ax, kws)
#    1414         for center, swarm in zip(centers, swarms):
#    1415             if swarm.get_offsets().size:
# -> 1416                 self.swarm_points(ax, swarm, center, width, s, **kws)
#    1417
#    1418     def plot(self, ax, kws):
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in swarm_points(self, ax, points, center, width, s, **kws)
#    1316
#    1317         # Do the beeswarm in point coordinates
# -> 1318         new_xy = self.beeswarm(orig_xy, d)
#    1319
#    1320         # Transform the point coordinates back to data coordinates
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in beeswarm(self, orig_xy, d)
#    1268
#    1269             # Find the first candidate that does not overlap any neighbours
# -> 1270             new_xy_i = self.first_non_overlapping_candidate(candidates,
#    1271                                                             neighbors, d)
#    1272
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in first_non_overlapping_candidate(self, candidates, neighbors, d)
#    1233             # and any of the neighbours has to be at least
#    1234             # square of the diameter
# -> 1235             good_candidate = np.all(sq_distances >= d_square)
#    1236
#    1237             if good_candidate:
#
# KeyboardInterrupt:

# %%
sns.swarmplot(y=imdb_subsample.sample(100, random_state=1), averageRating)

# %%
sns.scatterplot(x=imdb.averageRating, y=imdb.numVotes)
# Out:
# <AxesSubplot:xlabel='averageRating', ylabel='numVotes'>

# %%
imdb.averageRating = 1000

# %%
# mit der Methode apply kann eine Funktion auf alle Werte einer Series angewandt werde,
# es wird eine neue Series zurückgegeben, die die Rückgabewerte der Funktion entthält
def multiply_by_1000(number):
    return number * 1000

imdb.averageRating.apply(multiply_by_1000)
# Out:
# 0          1000000
# 1          1000000
# 2          1000000
# 3          1000000
# 4          1000000
#             ...
# 1154741    1000000
# 1154742    1000000
# 1154743    1000000
# 1154744    1000000
# 1154745    1000000
# Name: averageRating, Length: 1154746, dtype: int64

# %%
# Lambda Funktionen (Unbekannte funktionen)

imdb.averageRating.apply(lambda number : number * 1000)
# Out:
# 0          1000000
# 1          1000000
# 2          1000000
# 3          1000000
# 4          1000000
#             ...
# 1154741    1000000
# 1154742    1000000
# 1154743    1000000
# 1154744    1000000
# 1154745    1000000
# Name: averageRating, Length: 1154746, dtype: int64

# %%
# Wir generieren eine neue Spalte (Series), in der wir unsere Filme in zwei
#Klassen einteilen.
# Solche die 20 (Der Median) oder mehr Stimmen bekommen haben und solche
# die weniger Stimmen bekommen haben.

# %%
imdb_subsample["voting_class"] = imdb_subsample.numVotes.apply(
    lambda number : "more_or_equal_20" if number >= 20 else "less_than_20"
)

# %%
imdb_subsample
# Out:
#              tconst  averageRating  numVotes      voting_class
# 567082   tt12811614            7.3         7      less_than_20
# 1047770   tt7099552            7.1        47  more_or_equal_20
# 909243    tt4599394            8.2         5      less_than_20
# 270830    tt0522474            7.6        58  more_or_equal_20
# 839377    tt3442056            6.8         5      less_than_20
# ...             ...            ...       ...               ...
# 744608    tt2193114            7.0         6      less_than_20
# 938664    tt5138110            7.4         7      less_than_20
# 495015    tt1110245            6.7        10      less_than_20
# 508729   tt11377608            9.0         6      less_than_20
# 800263    tt2816994            9.6        23  more_or_equal_20
#
# [10000 rows x 4 columns]

# %%
sns.stripplot(data=imdb_subsample, y="averageRating", x="voting_class", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='voting_class', ylabel='averageRating'>

# %%
sns.boxplot(data=imdb_subsample, y="averageRating", x="voting_class")
# Out:
# <AxesSubplot:xlabel='voting_class', ylabel='averageRating'>
